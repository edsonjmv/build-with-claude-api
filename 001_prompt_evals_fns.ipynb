# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_s3_bucket(uri):\n    match = re.match(r's3://([^/]+)', uri)\n    return match.group(1) if match else None\n\n# Test\nprint(extract_s3_bucket('s3://my-bucket-name/path/to/file.txt'))\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI like 's3://my-bucket-name/path/to/file.txt' and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly solves the core task with a clean regex approach and demonstrates defensive programming by checking for match existence. However, it lacks robustness around input validation and edge cases that could occur in production AWS environments. The regex pattern itself is sound, but the function would benefit from explicit input checking and clearer documentation of expected input format."
#   },
#   {
#     "output": "\n{\n  \"MyLambdaFunction\": {\n    \"Type\": \"AWS::Lambda::Function\",\n    \"Properties\": {\n      \"FunctionName\": \"my-function\",\n      \"Runtime\": \"python3.11\",\n      \"Handler\": \"index.handler\",\n      \"Role\": \"arn:aws:iam::123456789012:role/lambda-execution-role\",\n      \"Code\": {\n        \"ZipFile\": \"def handler(event, context):\\n    return {'statusCode': 200}\\n\"\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS Lambda function resource with basic properties (FunctionName, Runtime, Handler, Role)",
#       "format": "json"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements a basic Lambda function CloudFormation resource with all required properties and valid JSON syntax. However, it has a notable limitation with the hardcoded account ID in the IAM role ARN, which violates infrastructure-as-code best practices. While the inline ZipFile approach works for simple examples, it's not production-ready for real-world scenarios. The template would benefit from using parameter references or outputs for the role ARN and S3-based code deployment."
#   },
#   {
#     "output": "\nimport re\n\ndef validate_ec2_instance_id(instance_id: str) -> bool:\n    \"\"\"\n    Validates that the instance ID matches the correct AWS EC2 format.\n    EC2 instance IDs should be 'i-' followed by 8 or 17 hexadecimal characters.\n    \"\"\"\n    pattern = r'^i-[a-f0-9]{8}$|^i-[a-f0-9]{17}$'\n    return bool(re.match(pattern, instance_id))\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        (\"i-1234abcd\", True),\n        (\"i-1234abcdef123456\", False),\n        (\"i-1234abcdef1234567\", True),\n        (\"i-12345678\", True),\n        (\"i-123456789\", False),\n        (\"i-\", False),\n        (\"1234abcd\", False),\n        (\"i-GGGGGGGG\", False),\n        (\"i-1a2b3c4d\", True),\n        (\"i-1a2b3c4d5e6f7890123\", False),\n    ]\n    \n    for instance_id, expected in test_cases:\n        result = validate_ec2_instance_id(instance_id)\n        print(f\"{instance_id}: {result} (expected: {expected}) {'\u2713' if result == expected else '\u2717'}\")\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS EC2 instance ID string and validates that it matches the correct format (i-followed by 8 or 17 hexadecimal characters)",
#       "format": "python"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements the core validation logic with an accurate regex pattern and good test coverage. However, it has two notable issues: (1) AWS EC2 instance IDs use uppercase hex characters in newer formats, so the pattern should be case-insensitive, and (2) the function lacks input validation for non-string types. These are relatively minor issues that wouldn't cause failures in most use cases but represent incomplete production-ready code."
#   }
# ]
